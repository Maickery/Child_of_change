# %% [markdown]
# <h1 align=center><font size = 8>Child of Change</font></h1>
#
# <div class="right">
# <center>
# <img src="./arm_haitien.jpg"  alt="drawing" width="110"/>
# </center>
# </div>

# %% [markdown]
# # Objective

# %% [markdown]
# * profiling teenage pregnancies
# * making predictions
# * reduce the rate of teenage pregnancies

# %% [markdown]
# # Hypothesis or research question

# %% [markdown]
# **Who are most likely to have an early pregnancy? Why?**

# %% [markdown]
# # Project plan
# * [Introduction](#introduction)
# * [Haitian demographics](#demographics)
# * [Data source](#source)
# * [Data cleaning](#cleaning)
# * [Data analysis](#analysis)
# * [Reflections](#Reflections)

# %% [markdown]
# # Introduction <a name="Introduction"></a>

# %% [markdown]
# Haiti is a Caribbean country located on the island of Hispaniola, with a young age structure, the 15 to 65 year olds make up 60% of its population. In a context of demographic transition, young people (15-24 years) have reached 21% of the population. Approximately 220,000 young people of both sexes will have reached the age of 15 each year, which is the age to enter the labour market or to engage in vocational training. Adolescents between the ages of 10 and 19 make up about 22% of the population.

# %% [markdown]
# **This phenomenon can be explained by:**
# - Lack of sexual information and education - Due to lack of resources and gender taboos, children and young girls do not receive sexual and reproductive education. They do not know or know little about contraception and the risks of early pregnancy. The lack of family planning, which is free in some developing countries, reinforces this situation of ignorance and lack of access to care.
# - Forced and early marriages - 9 out of 10 early pregnancies occur within marriage or cohabitation. Once married, girls are forced to have sex with their husbands and become pregnant.
# - Sexual violence and abuse - On the way to and from school, in schools, in emergencies, within the family - girls are vulnerable to unprotected sexual violence and abuse.
# - Cultural taboos - In some developing countries, talking about sex is taboo. Girls who become pregnant as a result of sex or sexual abuse are ashamed to talk about it and therefore do nothing to stop it.
# - The law - In most developing countries, abortion and sometimes even contraception are considered a crime and are punishable.
# - Access to contraception - Access to contraception can be hindered by poverty, taboos and/or distances too great to reach a shop or health center distributing them.

# %% [markdown]
# A girl's pregnancy can radically change her life. She may be forced to drop out of school, reducing her employment prospects. She also becomes more vulnerable to poverty and exclusion. Her health can also suffer, as complications related to pregnancy and childbirth are one of the leading causes of death among adolescents.
# Adolescent pregnancy is usually less a deliberate choice than a lack of choice: it is the consequence of little or no access to education, information and health care.
# **Who are most likely to have an early pregnancy in Haiti? And Why?**

# %% [markdown]
# # Haitian demographics <a name="Haitian demographics"></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r'Haiti_Data') # Load the csv

# %%
df
# Out:
#   Code adm0_en Depart_code      adm1_en      lat      lng         Total  \
# 0   HT   Haiti        HT05   Artibonite  19.4504 -72.6832  2.047153e+06
# 1   HT   Haiti        HT06       Centre  19.1430 -72.0040  8.455942e+05
# 2   HT   Haiti        HT08  Grande'Anse  18.6339 -74.1184  4.810653e+05
# 3   HT   Haiti        HT10       Nippes  18.4411 -73.0883  3.515933e+05
# 4   HT   Haiti        HT03        North  19.7592 -72.2125  1.159762e+06
# 5   HT   Haiti        HT04   North-East  19.6656 -71.8448  4.444631e+05
# 6   HT   Haiti        HT09   North-West  19.9318 -72.8295  8.685806e+05
# 7   HT   Haiti        HT07        South  18.5410 -72.3360  7.910850e+05
# 8   HT   Haiti        HT02   South-East  18.2004 -73.7500  8.939007e+05
# 9   HT   Haiti        HT01         West  18.2350 -72.5370  5.010206e+06
#
#     Female     Male
# 0  1034065  1013085
# 1   413649   431947
# 2   229914   251152
# 3   167185   184409
# 4   589825   569932
# 5   221501   222966
# 6   437975   430605
# 7   382084   409000
# 8   448111   445790
# 9  2587360  2422846

# %%
print('Haiti has {} haitians including {} females and {} males.'.format(df['Total'].sum(), df['Female'].sum(), df['Male'].sum()))
# Out:
# Haiti has 12893401.77166054 haitians including 6511669 females and 6381732 males.

# %%
import folium 
from folium.plugins import MarkerCluster
from folium.map import Icon

# %%
#Create haitian map with coordinates of each department
latitude= 19.0558462 
longitude= -73.0513321
map_haiti = folium.Map(location=[latitude, longitude], zoom_start=9, tiles='CartoDB positron')
marker_cluster = MarkerCluster().add_to(map_haiti)

for lat, lng, Total, Female, Male in zip(df['lat'], df['lng'], df['Total'], df['Female'],df['Male']):
    label = 'Total: {}, Female: {}, Male: {}'.format(round(Total,0), Female, Male)
    label = folium.Popup(label, parse_html=True)
    folium.Marker(
        [lat, lng],
        #radius=5,
        popup=label,
        #color='blue',
        #fill=True,
        #fill_color='#3186cc',
        #fill_opacity=0.7,
        #parse_html=False,
        icon=Icon(color='red', icon_color='yellow', icon='check-circle',prefix='fa')).add_to(marker_cluster)  
    
map_haiti
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - the average age at first sexual intercourse is 13;
# - 3% of teenage girls have already had 3 children;
# - the maximum number of pregnancies is 5;
# - 57% of the mothers of the teenage girls surveyed have already been fertile before the age of 20;
# - only 12% of sexual information is provided by family and 29% by friends;
# - only 16% of the progenitors are adolescents and 47% are over 28 years of age;
# - 93% of adolescent girls do not use condoms or use them only sometimes;
# - 90% do not know about family planning methods and how they work;
# - 92% do not know their menstrual cycle and 88% do not know their fertile period"

# %% [markdown]
# **Knowing that young people (15-24 years) represent 21% of the population, let us assume that this applies to each of the following departments for female only**

# %%
def femyoung_percent(percent =0.21,df=None):
    df['21 % of female'] = df.Female.apply(lambda x: x*percent)
    return df

# %%
df1 =femyoung_percent(percent=0.21,df=df)

# %%
df1
# Out:
#   Code adm0_en Depart_code      adm1_en      lat      lng         Total  \
# 0   HT   Haiti        HT05   Artibonite  19.4504 -72.6832  2.047153e+06
# 1   HT   Haiti        HT06       Centre  19.1430 -72.0040  8.455942e+05
# 2   HT   Haiti        HT08  Grande'Anse  18.6339 -74.1184  4.810653e+05
# 3   HT   Haiti        HT10       Nippes  18.4411 -73.0883  3.515933e+05
# 4   HT   Haiti        HT03        North  19.7592 -72.2125  1.159762e+06
# 5   HT   Haiti        HT04   North-East  19.6656 -71.8448  4.444631e+05
# 6   HT   Haiti        HT09   North-West  19.9318 -72.8295  8.685806e+05
# 7   HT   Haiti        HT07        South  18.5410 -72.3360  7.910850e+05
# 8   HT   Haiti        HT02   South-East  18.2004 -73.7500  8.939007e+05
# 9   HT   Haiti        HT01         West  18.2350 -72.5370  5.010206e+06
#
#     Female     Male  21 % of female
# 0  1034065  1013085       217153.65
# 1   413649   431947        86866.29
# 2   229914   251152        48281.94
# 3   167185   184409        35108.85
# 4   589825   569932       123863.25
# 5   221501   222966        46515.21
# 6   437975   430605        91974.75
# 7   382084   409000        80237.64
# 8   448111   445790        94103.31
# 9  2587360  2422846       543345.60

# %%
# sonje aplike yon fonksyon lamba pouw round e +1 sou pousantaj

# %%
df1.describe().drop(columns=['lat','lng'])
# Out:
#               Total        Female          Male  21 % of female
# count  1.000000e+01  1.000000e+01  1.000000e+01       10.000000
# mean   1.289340e+06  6.511669e+05  6.381732e+05   136745.049000
# std    1.392878e+06  7.234966e+05  6.694527e+05   151934.280321
# min    3.515933e+05  1.671850e+05  1.844090e+05    35108.850000
# 25%    5.585702e+05  2.679565e+05  2.906140e+05    56270.865000
# 50%    8.570874e+05  4.258120e+05  4.312760e+05    89420.520000
# 75%    1.093296e+06  5.543965e+05  5.388965e+05   116423.265000
# max    5.010206e+06  2.587360e+06  2.422846e+06   543345.600000

# %%
print('Haiti has {} haitians young females.'.format(round  (df['21 % of female'].sum(),1)))
# Out:
# Haiti has 1367450.5 haitians young females.

# %%
#to find categorical values
col_cat = ['Female', 'Male']
for col in col_cat:
    print(col, df1[col].unique())
# Out:
# Female [1034065  413649  229914  167185  589825  221501  437975  382084  448111
#  2587360]
# Male [1013085  431947  251152  184409  569932  222966  430605  409000  445790
#  2422846]

# %%
from matplotlib import pyplot as plt
df1.reset_index ().plot (
    x = "index" , y = [ "Female" , "Male" ] , kind = "bar"
)
plt. title ( "Haitian demographics" )
plt. xlabel ( "adm1_en" )
plt. ylabel ( "Total" )
# Out:
# Text(0, 0.5, 'Total')

# %%
df_keys = pd.read_csv(r'Keys indicateur').drop(columns=['men']) # Load the csv
df_keys
# Out:
#                                         variable_name  \
# 0                 Percentage of youth who cannot read
# 1                 Percentage of youth who cannot read
# 2                 Percentage of youth who cannot read
# 3   Percentage of youth with completed primary edu...
# 4   Percentage of youth with completed primary edu...
# 5   Percentage of youth with completed primary edu...
# 6   Percentage of youth exposed to at least one me...
# 7   Percentage of youth exposed to at least one me...
# 8   Percentage of youth exposed to at least one me...
# 9               Percentage of youth currently married
# 10              Percentage of youth currently married
# 11              Percentage of youth currently married
# 12      Percentage of youth currently living together
# 13      Percentage of youth currently living together
# 14      Percentage of youth currently living together
# 15  Percentage of youth who had sexual intercourse...
# 16  Percentage of youth who had sexual intercourse...
# 17  Percentage of youth who had sexual intercourse...
# 18  Percentage of youth who had sexual intercourse...
# 19             Median age at first sexual intercourse
# 20               2.1 Teenage pregnancy and motherhood
# 21               2.1 Teenage pregnancy and motherhood
# 22  Percentage of youth currently using a modern c...
# 23  Percentage of youth currently using a modern c...
# 24  Percentage of youth currently using a modern c...
# 25  Percentage of sexually active youth who have e...
# 26  Percentage of sexually active youth who have e...
# 27  Percentage of sexually active youth who have e...
# 28  Percentage of youth who have had sexual interc...
# 29  Percentage of youth who have had sexual interc...
# 30  Percentage of youth who have had sexual interc...
#
#                                             age_group women
# 0                                               15-19  17.9
# 1                                               20-24  19.1
# 2                                               15-24  18.5
# 3                                               15-19  48.8
# 4                                               20-24  60.0
# 5                                               15-24  53.6
# 6                                               15-19  82.8
# 7                                               20-24  82.6
# 8                                               15-24  82.7
# 9                                               15-19   5.7
# 10                                              20-24  29.9
# 11                                              15-24  16.0
# 12                                              15-19  10.9
# 13                                              20-24  23.8
# 14                                              15-24  16.4
# 15                                              15-19  15.3
# 16                                              20-24  13.5
# 17                                              15-24  14.6
# 18                                              18-24  54.8
# 19                                              18-24     u
# 20  Percentage of youth (age 15-19) who have begun...  14.0
# 21  Percentage of youth age 15-19 who have ever be...  14.5
# 22                                              15-19   7.5
# 23                                              20-24  19.5
# 24                                              15-24  12.6
# 25                                              15-19  59.9
# 26                                              20-24  70.6
# 27                                              15-24  67.2
# 28                                              15-19  22.6
# 29                                              20-24  20.0
# 30                                              15-24  20.9

# %%
#rename rows 20&21

# %% [markdown]
# ### Identify clusters within the dataset
# Use K-Elbow plot to identify optimal number of clusters
# Run K-Mean clustering algorithm to identify nearest nehbots

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster.elbow import kelbow_visualizer

# Use the quick method and immediately show the figure
kelbow_visualizer(KMeans(random_state=4), df_keys, k=(2,10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-50426acabffc> in <module>
#       1 from sklearn.cluster import KMeans
# ----> 2 from yellowbrick.cluster.elbow import kelbow_visualizer
#       3
#       4 # Use the quick method and immediately show the figure
#       5 kelbow_visualizer(KMeans(random_state=4), df_keys, k=(2,10))
#
# ModuleNotFoundError: No module named 'yellowbrick'
